# %%
# !streamlit run "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py"
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.10.179:8501
#
# 2025-07-08 21:36:07.112 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:07.114 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:07.114 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:07.115 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:07.116 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 151, in render
#     st.metric(label="", value=pen_score, delta=f"{st.session_state.game['penalty']}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.005 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.008 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.010 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.013 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.014 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 151, in render
#     st.metric(label="", value=pen_score, delta=f"{st.session_state.game['penalty']}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.818 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.821 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.823 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.824 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:10.826 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 151, in render
#     st.metric(label="", value=pen_score, delta=f"{st.session_state.game['penalty']}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:11.513 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:11.515 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:11.518 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 147, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:36:11.521 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
# ...
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:51:19.287 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 164, in render
#     st.metric(label="", value=pen_score, delta=f"{st.session_state.game['penalty']}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:51:26.849 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 160, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:51:26.850 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 160, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:51:26.852 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 160, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:51:26.854 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 160, in render
#     st.metric(label="", value=score, delta=f"{delta}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# 2025-07-08 21:51:26.855 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# Stack (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 378, in _run_script_thread
#     self._run_script(request.rerun_data)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 685, in _run_script
#     ) = exec_func_with_error_handling(code_to_exec, ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 128, in exec_func_with_error_handling
#     result = func()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 70, in <module>
#     main()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/qwixx.py", line 49, in main
#     scoresheet.render()
#   File "/Volumes/TAFOL/Daniel Cooke/Work & Learning/Learning/Python/Streamlit/Qwixx-ScoreSheet/scoresheet.py", line 164, in render
#     st.metric(label="", value=pen_score, delta=f"{st.session_state.game['penalty']}×")
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py", line 443, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/metric.py", line 202, in metric
#     maybe_raise_label_warnings(label, label_visibility)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/lib/policies.py", line 184, in maybe_raise_label_warnings
#     _LOGGER.warning(
# ^C
